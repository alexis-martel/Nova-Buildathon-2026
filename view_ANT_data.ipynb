# %%
import mne
mne.viz.set_browser_backend('qt')
# Out:
# Using qt as 2D backend.

# %%
ant_data = mne.io.read_raw_ant("dataset/ANT_EEG_flipcup/Ewing_Patrick_2026-08-10_13-07-25_session-01.cnt")
# Out:
# Reading ANT file dataset/ANT_EEG_flipcup/Ewing_Patrick_2026-08-10_13-07-25_session-01.cnt
# All 64 EEG channels are referenced to CPz.

# %%
ant_data.plot()
# Out:
# Channels marked as bad:
# [np.str_('FC2')]

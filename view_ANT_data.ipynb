# %%
import mne

mne.viz.set_browser_backend("qt")

# %%
ant_data = mne.io.read_raw_ant(
    "dataset/ANT_EEG_flipcup/Ewing_Patrick_2026-08-10_13-07-25_session-01.cnt"
)

# %%
ant_data.plot()

# %%
#comment
